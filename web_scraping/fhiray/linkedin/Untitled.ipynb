# %%
import time
import pandas as pd

from IPython.display import clear_output

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.google.com")

# %%
def scroll():
    previous_heigth = driver.execute_script('return document.body.scrollHeight')
    while True:
        driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
        time.sleep(2)
        new_heigth = driver.execute_script('return document.body.scrollHeight')
        if new_heigth == previous_heigth:
            break
        previous_heigth = new_heigth

# %%
driver.execute_script('window.scrollTo(0,2000);')

# %%
link.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# /tmp/ipykernel_10233/317941763.py in <module>
# ----> 1 link.click()
#
# ~/anaconda3/envs/ws/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      86     def click(self) -> None:
#      87         """Clicks the element."""
# ---> 88         self._execute(Command.CLICK_ELEMENT)
#      89
#      90     def submit(self):
#
# ~/anaconda3/envs/ws/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     394             params = {}
#     395         params['id'] = self._id
# --> 396         return self._parent.execute(command, params)
#     397
#     398     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ~/anaconda3/envs/ws/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
driver.find_elements('xpath','//span[@class="entity-result__title-line entity-result__title-line--2-lines"]//a')[8].click()

# %%
driver.find_element('xpath', '//button[@aria-label="Next"]')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="932e114cc644471da12b26ac058f1611", element="fd9ec044-6a84-46f7-a25c-f19c06802cb8")>

# %%
driver.current_url
# Out:
# 'https://www.linkedin.com/search/results/people/?geoUrn=%5B%22104305776%22%5D&keywords=nurse&lastName=nurse&origin=FACETED_SEARCH&sid=XkN'

# %%
200 * 10
# Out:
# 2000

# %%
# nurse_eau = pd.DataFrame(box)

# %%
# nurse_india = pd.DataFrame(box)

# %%
nurse_india2 = pd.DataFrame(box)

# %%
nurse_fili = pd.DataFrame(box)

# %%
df = pd.concat([nurse_eau, nurse_india, nurse_india2, nurse_fili, df_s]).drop_duplicates()

# %%
df

# %%
df_s = pd.DataFrame(box)

# %%
# box = []
for pagei in range(100):
    print(f'Page numero {pagei}')
    try:
        links = driver.find_elements('xpath','//span[@class="entity-result__title-line entity-result__title-line--2-lines"]//a//span[@aria-hidden="true"]')
        names = [i.text for i in driver.find_elements('xpath','//span[@class="entity-result__title-line entity-result__title-line--2-lines"]//a//span[@aria-hidden="true"]')]
        for idx, _ in enumerate(links):
            if idx != 0:
                x = (idx ) * 100
            else:
                x = 0
            driver.execute_script(f'window.scrollTo(0,{x});')
            driver.find_elements('xpath','//span[@class="entity-result__title-line entity-result__title-line--2-lines"]//a//span[@aria-hidden="true"]')[idx].click()
            time.sleep(2)
            scroll()
            url = driver.current_url
            try:
                current_job = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//div[@class="display-flex align-items-center"]').text
                current_job = current_job.split('\n')[0]
            except:
                curren_job = None

            try:
                current_location_job = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//span[@class="t-14 t-normal t-black--light"][position()=2]').text
                current_location_job = current_location_job.split('\n')[0]
            except:
                current_location_job = None

            try:
                current_time_in_job = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//span[@class="t-14 t-normal t-black--light"][position()=1]').text
                current_time_in_job = current_time_in_job.split('\n')[0]
            except:
                current_time_in_job = None

            try:
                current_company = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//span[@class="t-14 t-normal"]').text
                current_company = current_company.split('\n')[0]
            except:
                current_company = None

            try:
                education = driver.find_element('xpath', '//section[contains(.,"Education")][@class="artdeco-card ember-view relative break-words pb3 mt2 "]/div[@id="education"]/..//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"]').text
                education_box = []

                for i in education.split('\n'):
                    if i in education_box:
                        continue
                    education_box.append(i)

                education = ' - '.join(education_box)
            except:
                education = None

            box.append({
                'First Name': names[idx].split()[0],
                'Last Name':  names[idx].split()[1],
                'Link':url,
                'Current Job': current_job,
                'Current Company': current_company,
                'Current time in company': current_time_in_job,
                'Location Company': current_location_job,
                'Education': education
            })

            driver.back()
            time.sleep(2)

        scroll()
        driver.find_element('xpath', '//button[@aria-label="Next"]').click()
        time.sleep(5)
    except Exception as ex:
        print(ex)
        print(f'Error Page numero {pagei}')
        pass
# Out:
# Page numero 0
# Page numero 1
# Page numero 2
# Page numero 3
# Page numero 4
# Page numero 5
# Page numero 6
# Page numero 7
# Page numero 8
# Page numero 9
# Page numero 10
# Page numero 11
# Page numero 12
# Page numero 13
# Page numero 14
# Page numero 15
# Page numero 16
# Page numero 17
# Page numero 18
# Page numero 19
# Page numero 20
# Page numero 21
# Page numero 22
# Page numero 23
# Page numero 24
# Page numero 25
# Page numero 26
# Page numero 27
# Page numero 28
# Page numero 29
# Page numero 30
# Page numero 31
# Page numero 32
# Page numero 33
# Page numero 34
# Page numero 35
# Page numero 36
# Page numero 37
# Page numero 38
# Page numero 39
# Page numero 40
# Page numero 41
# Page numero 42
# Page numero 43
# Page numero 44
# Page numero 45
# Page numero 46
# Page numero 47
# Page numero 48
# Page numero 49
# Page numero 50
# Page numero 51
# Page numero 52
# Page numero 53
# Page numero 54
# Page numero 55
# Page numero 56
# Page numero 57
# Page numero 58
# ...

# %%
current_job = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//div[@class="display-flex align-items-center"]').text
current_job = current_job.split('\n')[0]

# %%
current_time_in_job = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//span[@class="t-14 t-normal t-black--light"][position()=1]').text
current_time_in_job = current_time_in_job.split('\n')[0]

# %%
current_location_job = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//span[@class="t-14 t-normal t-black--light"][position()=2]').text
current_location_job = current_location_job.split('\n')[0]

# %%
current_company = driver.find_element('xpath', '//section[contains(.,"Experience")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"][position()=1]//span[@class="t-14 t-normal"]').text
current_company = current_company.split('\n')[0]

# %%
string_box = []

# %%
for string in current_job.split(' - '):
    if string  in string_box:
        continue 
    string_box.append(string)

# %%
string_box
# Out:
# ['Nursing Manager OPD',
#  'Fakih IVF Fertility Center',
#  'Full-time',
#  'Jun 2022',
#  'Present',
#  '5 mos',
#  'Abu Dhabi, United Arab Emirates',
#  'Skills: In Vitro Fertilization (IVF) Nursing',
#  'Nursing Management',
#  'Team Motivation',
#  'Nursing',
#  'Leadership',
#  'Teamwork',
#  'Fertility',
#  'Communication',
#  'In Vitro Fertilization (IVF) Nursing']

# %%
current_job_title   = string_box[0]
current_company     = string_box[1]
current_time_in_job = ' '.join(string_box[3:6])

# %%
return {
    'Current Job': current_job,
    'Current Company': current_company,
    'Location Company': location_company,
    'Education': education
}

# %%
education = driver.find_element('xpath', '//section[contains(.,"Education")]//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"]//div[@class="display-flex align-items-center"]').text
education = education.split('\n')[0]

# %%
education
# Out:
# 'Nursing Manager OPD'

# %%
education = driver.find_element('xpath', '//section[contains(.,"Education")][@class="artdeco-card ember-view relative break-words pb3 mt2 "]/div[@id="education"]/..//li[@class="artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column"]').text

# %%
education_box = []

for i in education.split('\n'):
    if i in education_box:
        continue
    education_box.append(i)

# %%
' - '.join(education_box)
# Out:
# "Alexandria University - Bachelor's degree, Fertility nurse - 2000 - 2004"

# %%
box = []
for idx, i in enumerate(range(16)):
    print('Scraping ...')
    time.sleep(5)
    scroll()
    links = [i.get_attribute('href') for i in driver.find_elements('xpath', '//ul/li//span[@class="entity-result__title-text\n        t-16"]/a')]
    names = [i.text for i in driver.find_elements('xpath','//span[@class="entity-result__title-line entity-result__title-line--2-lines"]//a//span[@aria-hidden="true"]')]
    position = [i.text for i in driver.find_elements('xpath','//div[@class="linked-area flex-1\n    cursor-pointer"]/div[@class="entity-result__primary-subtitle t-14 t-black t-normal"]')]
    location = [i.text for i in driver.find_elements('xpath','//div[@class="linked-area flex-1\n    cursor-pointer"]/div[@class="entity-result__secondary-subtitle t-14 t-normal"]')]
    print(len(links))
    for idx, name in enumerate(names):
        box.append({
            'Links':links[idx],
            'Names':name,
            'Position':position[idx],
            'Location':location[idx]

            })
    time.sleep(5)
    driver.find_element('xpath', '//button[@aria-label="Siguiente"]').click()
    print(f'Page {idx} completed')
# Out:
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 10
# Page 9 completed
# Scraping ...
# 4
# Page 3 completed
# Scraping ...
# 4
# Page 3 completed
# Scraping ...
# 4
# Page 3 completed

# %%
df = pd.DataFrame(box)

# %%
df
# Out:
#                                                  Links  \
# 0    https://www.linkedin.com/in/anjali-vijayan-825...
# 1    https://www.linkedin.com/in/alvinperucho?miniP...
# 2    https://www.linkedin.com/in/linda-chi-chi-obaa...
# 3    https://www.linkedin.com/in/hanadi-mokhtar-811...
# 4    https://www.linkedin.com/in/azza-abd-elrahim-5...
# ..                                                 ...
# 137  https://www.linkedin.com/in/mahdi-nurse-23b612...
# 138  https://www.linkedin.com/in/male-nurse-0090a85...
# 139  https://www.linkedin.com/in/jsh-nurse-and-doct...
# 140  https://www.linkedin.com/in/jesly-mathew-nurse...
# 141  https://www.linkedin.com/in/mahdi-nurse-23b612...
#
#                                                  Names  \
# 0                                       Anjali Vijayan
# 1    Alvin Perucho, BSN, RN, Operating Room Staff N...
# 2    Linda Chi-Chi Obaah Provider.Covid Response Nu...
# 3                                       Hanadi Mokhtar
# ...

# %%
df.to_csv('//mnt/c/Users/cesar/Desktop/results_12_10.csv', index=False)

# %%
driver.get('https://www.linkedin.com/search/results/PEOPLE/?geoUrn=%5B%22104305776%22%5D&keywords=nurse&lastName=Nurse&origin=FACETED_SEARCH&sid=c%40H')

# %%
# Out:
# ['https://www.linkedin.com/in/anjali-vijayan-825a87168?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACgGs90BxZVEo_Ol0bbx2R5EW5wYmznkZBk',
#  'https://www.linkedin.com/in/alvinperucho?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACL1WtgBTi9o-xwGTvtuFYZLy4GGGNA2HWw',
#  'https://www.linkedin.com/in/linda-chi-chi-obaah-provider-covid-response-nurse-rentnp-91b51621a?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADc_2qcBCHOZXQSdJFX6P7YDPeT1vQMLOl0',
#  'https://www.linkedin.com/in/hanadi-mokhtar-811049242?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADwppU0BEXFixmMrf9ZbaVXdXiDsTWiaDOI',
#  'https://www.linkedin.com/in/azza-abd-elrahim-570120197?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAC4dISQBTaYskvqxEWyTybv4qmh6q2THPc8',
#  'https://www.linkedin.com/in/soha-abou-nour-26618918?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAOV0i4Bfa2jjVu5gMJNQvsHH9m4_umhWPk',
# ...

# %%
df
# Out:
#                                                 Links  \
# 0   [https://www.linkedin.com/in/anjali-vijayan-82...
# 1   [https://www.linkedin.com/in/jincy-pappachan-r...
# 2   [https://www.linkedin.com/in/registered-nurse-...
# 3   [https://www.linkedin.com/in/alaa-ghareeb-8227...
# 4   [https://www.linkedin.com/in/reena-dsouza-7445...
# 5   [https://www.linkedin.com/in/clotilda-pinto-fe...
# 6   [https://www.linkedin.com/in/veronica-alapide-...
# 7   [https://www.linkedin.com/in/sunshine-joy-abad...
# 8   [https://www.linkedin.com/in/anitha-angeline-d...
# 9   [https://www.linkedin.com/in/noor-jad-school-n...
# 10  [https://www.linkedin.com/in/sijo-nurse-b742a0...
# 11  [https://www.linkedin.com/in/ghq-pass-nurse-ha...
# 12  [https://www.linkedin.com/in/marina-nurse-3211...
# 13  [https://www.linkedin.com/in/male-nurse-0090a8...
# 14  [https://www.linkedin.com/in/male-nurse-0090a8...
# 15  [https://www.linkedin.com/in/male-nurse-0090a8...
#
# ...

# %%
# Out:
# ['Registered Nurse',
#  'Operating Room Registered Nurse at SKMC',
#  'Registered Nurse at Iqarus',
#  'registered nurse',
#  'mawi day surgical centre',
#  'Fertility nurse who’s passionate about my career',
#  'Bachelor in nursing',
#  '--Registered nurse With DHA Eligibility letter',
#  'PhRN, HAAD-RN, USRN',
#  'Registered Nurse - Operation Theatre']

# %%
# Out:
# ['Emiratos Árabes Unidos',
#  'Abu Dhabi / Abu Zabi, Emiratos Árabes Unidos',
#  'Dubai, Emiratos Árabes Unidos',
#  'Dubai',
#  'Dubai, Emiratos Árabes Unidos',
#  'Abu Dhabi / Abu Zabi, Emiratos Árabes Unidos',
#  'al-‘Ayn',
#  'Dubai',
#  'Abu Dhabi / Abu Zabi, Emiratos Árabes Unidos',
#  'Emiratos Árabes Unidos']

# %%
import pickle

# %%
with open('list_profiles', 'wb') as fp:
    pickle.dump(box, fp)

# %%
with open('list_profiles', 'rb') as fp:
    a = pickle.load(fp)

# %%
a
# Out:
# ['https://www.linkedin.com/in/pia-dahl-ibd-pe-nurse-at-rigshospitalet-97282169?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAA6JniYBc2ffUGCBnTDSiy2612ePSG3IhKw',
#  'https://www.linkedin.com/in/kate-nurse-a2b0231a5?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAC_hDAMB7D9mvtG5yL-bk8EPiNB1vVWRwmg',
#  'https://www.linkedin.com/in/lorcan-nurse-ca-sa-33369679?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABCnG1cBBpSB6TT6LZ5xPvJAcX_voaMBufc',
#  'https://www.linkedin.com/in/inge-bitsch-8257082a?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAYn7p0BnmbfYCTR_UzAKtYtfBJPOogh2PA',
#  'https://www.linkedin.com/in/jason-nurse-656091103?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABosk2IBFcYxr61KpaWG4xhvzAcgXA7wrpA',
#  'https://www.linkedin.com/in/nick-nurse-48336415?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAMT96MBuBGd7PgTFN9AcqaQTpUGbE8Iwig',
#  'https://www.linkedin.com/in/dpegcn?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAqaKe4BevWnZOpO4TPENPv9A2jO0heJiro',
# ...

# %%
len(box)
# Out:
# 1000

# %%
driver.find_element('xpath', '//button[@aria-label="Siguiente"]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /tmp/ipykernel_7749/3621345115.py in <module>
# ----> 1 driver.find_element('xpath', '//button[@aria-label="Siguiente"]').click()
#
# ~/anaconda3/envs/ws/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     853             value = '[name="%s"]' % value
#     854
# --> 855         return self.execute(Command.FIND_ELEMENT, {
#     856             'using': by,
#     857             'value': value})['value']
#
# ~/anaconda3/envs/ws/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     426         response = self.command_executor.execute(driver_command, params)
#     427         if response:
# --> 428             self.error_handler.check_response(response)
#     429             response['value'] = self._unwrap_value(
# ...

# %%
a.extend([i.get_attribute('href') for i in driver.find_elements('xpath', '//ul/li//span[@class="entity-result__title-text\n        t-16"]/a')])

# %%
driver.get(box[0])

# %%
driver.get(box[0])

# %%
# ocupacion = driver.find_element('xpath', '//div[@class="text-body-medium break-words"]').text
# ocupacion

# %%
name = driver.find_element('xpath','//h1').text
name
# Out:
# 'Pia Dahl IBD / PE nurse at Rigshospitalet'

# %%
current_job = driver.find_element('xpath', '//div[@id="experience"]/..//ul/li[position()=1]//div[@class="display-flex align-items-center"]//span[@aria-hidden="true"]').text

# %%
current_company = driver.find_element('xpath', '//div[@id="experience"]/..//ul/li[position()=1]//span[@class="t-14 t-normal"]//span[@aria-hidden="true"]').text

# %%
location = driver.find_element('xpath', '//span[@class="text-body-small inline t-black--light break-words"]').text

# %%
a = None

# %%
f'Hola {a}'
# Out:
# 'Hola None'

# %%
# data= []

# %%
driver.get('https://www.linkedin.com/in/marcos-laurens/')

# %%
47-15
# Out:
# 32

# %%
data[33]
# Out:
# {'Name': 'Join LinkedIn',
#  'Current Job': 'None / None',
#  'Location': None,
#  'Linkedin Profile': 'https://www.linkedin.com/in/s-nurse-bpim?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAB5UmDwB3RrSqamWE38sfwNW5O0OjYaLb10'}

# %%
import random

# %%
print(random.randint(30,60))
# Out:
# 60

# %%
len(data)
# Out:
# 81

# %%
for idx, i in enumerate(box[80:]):
    if idx % 10 == 0:
        driver.get('https://www.linkedin.com/feed/')
        time.sleep(random.randint(60,120))
        
    time.sleep(random.randint(30,60))
    driver.get(i)
    try:
        name = driver.find_element('xpath','//h1').text
        if name == 'Únete a LinkedIn' or name == 'Join LinkedIn' or name == None:
            input(' ')
            name = driver.find_element('xpath','//h1').text
    except:
        name = None
    try:
        current_job = driver.find_element('xpath', '//div[@id="experience"]/..//ul/li[position()=1]//div[@class="display-flex align-items-center"]//span[@aria-hidden="true"]').text
        driver.find_element('xpath', '//div[@id="experience"]/..//ul/li[position()=1]//div[@class="display-flex align-items-center"]//span[@aria-hidden="true"]').click()
    except:
        current_job = None
    try:
        current_company = driver.find_element('xpath', '//div[@id="experience"]/..//ul/li[position()=1]//span[@class="t-14 t-normal"]//span[@aria-hidden="true"]').text
    except:
        current_company = None
    try:
        location = driver.find_element('xpath', '//span[@class="text-body-small inline t-black--light break-words"]').text
    except:
        location = None
        
    scroll()
    
    data.append(
        {
            'Name':name,
            'Current Job': f'{current_job} / {current_company}',
            'Location': location,
            'Linkedin Profile': i
        }
    )
    print(f'Scraped {name} / {current_job}-{current_company} / {location}')
# Out:
# Scraped Helen Nurse / Media creative agency Owner, specialising in digital marketing for education, video, events-Capture 1 DVP Ltd. / Lymm, England, United Kingdom
# Scraped Roderick Nurse / Einkäufer-Mercedes Benz Minibus GmbH / Ruhr Region
# Scraped Mark Nurse / Information Security Manager-Circulor · Full-time / United Kingdom
# Scraped Angie Nurse / None-None / France
# Scraped Dave Nurse / Divisional Sales Manager-Oak Furnitureland · Full-time / Nottingham, England, United Kingdom
# Scraped Joanna Nurse / Strategic Advisor-InterAction Council  / United Kingdom
# Scraped James Nurse / FINTRAIL-None / None
# Scraped Helen Nurse / None-None / Spain
# Scraped Euro Nurse / Medical Nurse Recruiter-Euro-Nurse / Romania
# Scraped Tina Gehring / Trustee-BRITISH ASSOCIATION OF UROLOGICAL NURSES / Greater Southampton Area
# Scraped Daniel Nurse / Software Developer-Nelson Schoenen BV / Hoofddorp, North Holland, Netherlands
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df = df[df['Current Job'] != 'None / Nonwe']

# %%
def ver(x):
    if 'Nurse' in x:
        return (x)
    else:
        return ('None')

# %%
cu = df['Current Job'].apply(lambda x : ver(x))

# %%
df['cu'] = cu

# %%
df[df['cu'] != 'None']
# Out:
#                                                   Name  \
# 0            Pia Dahl IBD / PE nurse at Rigshospitalet
# 3    Inge (Charge Nurse, Gentofte Hospital, Denmark...
# 4                                          Jason Nurse
# 7                                      Genevieve Nurse
# 10                            Armaiti Salamati (Nurse)
# 12                                      Rinnie de Haan
# 15                                 Alexandros Goulelis
# 59                          Maryam Ratilainen-Elabbasy
# 89                                          Euro Nurse
# 96                           Σάββας Παπαδόπουλος Nurse
# 102                                    Valentine Nurse
# 105                                     Sinead Watters
# 108                                   Sotiroulla Nurse
#
#                                            Current Job  \
# 0                               Nurse / Rigshospitalet
# 3                     Charge Nurse / Gentofte Hospital
# ...

# %%
df
# Out:
#    First Name Last Name                                               Link  \
# 0    Rajendra     Kumar  https://www.linkedin.com/in/rajendra-kumar-866...
# 1      Hanadi   Mokhtar  https://www.linkedin.com/in/hanadi-mokhtar-811...
# 2      Ansiya        An   https://www.linkedin.com/in/ansiya-an-90b42624b/
# 3      Anisha     Benny  https://www.linkedin.com/in/anisha-benny-a0790...
# 4      Wyslin      Hema            https://www.linkedin.com/in/wyslinhema/
# ..        ...       ...                                                ...
# 84      Leeba         K  https://www.linkedin.com/in/leeba-k-babu-3a957...
# 85       Rhea  Schuster  https://www.linkedin.com/in/rhea-schuster-b391...
# 86    Michael      John  https://www.linkedin.com/in/michael-john-pader...
# 87   Mathuren       Ndi  https://www.linkedin.com/in/mathuren-ndi-bb357...
# 88     Jackie        C.  https://www.linkedin.com/in/jackie-c-bacolores...
#
#                             Current Job  \
# ...

# %%
df.to_excel('//mnt/c/Users/cesar/Desktop/result_linkedin_30_10.xlsx')

# %%
import requests
from IPython.display import Image

# %%
r = requests.get('https://imgv2-1-f.scribdassets.com/img/document/444883036/original/a32aec8eac/1663633867?v=1')

# %%
with open('//mnt/c/Users/cesar/Desktop/image_comparison_chart.jpg', 'wb') as f:
    f.write(image)

# %%
image = r.content
