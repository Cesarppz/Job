# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
from selenium import webdriver


options = webdriver.ChromeOptions()
options.add_argument('--private')
# options.add_argument('--no-sandbox')
options.add_argument('user-agent=Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:102.0) Gecko/20100101 Firefox/102.0')
# fp = webdriver.ChromeProfile()
# fp.set_preference("dom.popup_maximum", 0)
driver = webdriver.Chrome(executable_path='/home/cesarppz/Documents/jobs/web_scraping/javier/agenda/driver/chromedriver', options=options)
# driver.implicitly_wait(7)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# /tmp/ipykernel_2980/3457545346.py in <module>
#       8 # fp = webdriver.ChromeProfile()
#       9 # fp.set_preference("dom.popup_maximum", 0)
# ---> 10 driver = webdriver.Chrome(executable_path='/home/cesarppz/Documents/jobs/web_scraping/javier/agenda/driver/chromedriver', options=options)
#      11 # driver.implicitly_wait(7)
#
# ~/anaconda3/envs/ws/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      74
#      75         try:
# ---> 76             RemoteWebDriver.__init__(
#      77                 self,
#      78                 command_executor=ChromeRemoteConnection(
#
# ...

# %%
url = 'https://www.idealista.com/39271960'

# %%
driver.get('https://www.google.com')

# %%
driver.get(url)

# %%
with open('info.log', 'a', encoding='utf-8') as file:
    file.write('\nHola')

# %%
with open('atributos.txt', 'r', encoding='utf-8') as file:
            file_attr = file.readlines()
        
        for i in file_attr[1:]:
            data = i.split(';')
            name_tag = data[0].lower().strip()
            attr_class = data[1].lower().strip()
            attr_name = data[2]
            print(name_tag,attr_class,attr_name)
            img = soup.find_all(name_tag, attrs={attr_class:attr_name})
            if img != []:
                break

# %%
for i in a[1:]:
    i= i.split(';')
    print(i)
# Out:
# ['hola', 'mmmm', 'adios ']

# %%
pattern = re.compile(r'https?://.*')

# %%
if not re.match(pattern, url):
    print('Hola')
# Out:
# Hola

# %%
url = 'https://static.inmofactory.com/images/inmofactory/documents/1/133542/30869922/483599255.jpg?rule=web_482x269'

# %%
url = '//images.habimg.com/imgh/4604-4049217/sant-salvador-dhorta-casa-girona_4604-img4049217-161469555G.jpg'

# %%
download_images.download(url, title_for_image='a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_30809/2435300188.py in <module>
# ----> 1 download_images.download(url, title_for_image='a')
#
# ~/Documents/jobs/web_scraping/javier/agenda_tools/download_images.py in download(image, second_try_image, nombre_del_lugar, idx, len_links, title_for_image, main_dir_name)
#      23     if image or second_try_image != None:
#      24             if image:
# ---> 25                 image_format = re.match(link_image_pattern,image).group(2)
#      26                 image_name = f'{nombre_del_lugar}_{idx}de{len_links}_{dia}_{mes}.{image_format}'
#      27                 if title_for_image != None:
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
r = requests.get(url)

# %%
from IPython.display import Image

# %%
Image(r.content)

# %%
int(df.shape[0])
# Out:
# 1203

# %%
for i in range(0,5):
    i

# %%
a = range(0,int(df.shape[0]))

# %%
a
# Out:
# range(0, 5)

# %%
len([i for i in a])
# Out:
# 1203

# %%
s = BeautifulSoup(r.text, 'lxml')

# %%
s.find_all('section', attrs={'class':'re-DetailMosaic re-DetailMosaic-grid5'})
# Out:
# [<section class="re-DetailMosaic re-DetailMosaic-grid5"><figure class="re-DetailMosaicPhotoWrapper re-DetailMosaicPhotoWrapper-photo1" role="button"><img alt="Foto 1 de Casa o chalet en venta en Albera, Palau, Girona" class="re-DetailMosaicPhoto" height="542" src="https://static.inmofactory.com/images/inmofactory/documents/1/118465/30306250/508134598.jpg?rule=web_948x542" title="Casa o chalet en venta en Albera, Palau, Girona - imagen 1" width="948"/></figure><figure class="re-DetailMosaicPhotoWrapper re-DetailMosaicPhotoWrapper-photo2" role="button"><img alt="Foto 2 de Casa o chalet en venta en Albera, Palau, Girona" class="re-DetailMosaicPhoto" height="269" src="https://static.inmofactory.com/images/inmofactory/documents/1/118465/30306250/508134599.jpg?rule=web_482x269" title="Casa o chalet en venta en Albera, Palau, Girona - imagen 2" width="482"/></figure><figure class="re-DetailMosaicPhotoWrapper re-DetailMosaicPhotoWrapper-photo3" role="button"><img alt="Foto 3 de Casa o chalet
# ...

# %%
s.find_all('div', attrs={'class':"ficha_foto flex-image n item"})
# Out:
# []

# %%
s.find_all('div', attrs={'class':"flex-images n"})
# Out:
# []

# %%
file = 'files/extraccion_fotos.xlsx'
names=['ID', 'URL']

# %%
df = pd.read_excel(file, header=1, names=names)
df.head()
# Out:
#                              ID  \
# 0  723hVUV1GGE420PNNNNNNNNhh26N
# 1   667FVUC1GGM42PNNSSSNNNhh29N
# 2  581hVUV1GGM422PSNSNNNNShh26N
# 3  419hVUV1GGC423PNNNNNNNNhh26N
# 4   2105FVUC1GGS42PSNNNNNNNh26N
#
#                                                  URL
# 0           https://www.habitaclia.com/i500004269597
# 1  https://www.fotocasa.es/Building/Building_Deta...
# 2           https://www.habitaclia.com/i500004348914
# 3           https://www.habitaclia.com/i500004421257
# 4  https://www.fotocasa.es/Building/Building_Deta...

# %%
df.loc[:, names[0]]
# Out:
# 0        723hVUV1GGE420PNNNNNNNNhh26N
# 1         667FVUC1GGM42PNNSSSNNNhh29N
# 2        581hVUV1GGM422PSNSNNNNShh26N
# 3        419hVUV1GGC423PNNNNNNNNhh26N
# 4         2105FVUC1GGS42PSNNNNNNNh26N
#                     ...
# 1198     842F1VPP1GGC42PSSNNSNNNhh29N
# 1199    1032F0VPD1GGE42PNSNNNNNNhh29N
# 1200      672FVPPGGE420PSSNNNNNNhh26N
# 1201     8210FVPAGGC421PSSNNNNNNhh26N
# 1202      146FVPÁ1GGE426PSSNSSNSNh29N
# Name: ID, Length: 1203, dtype: object

# %%
with sync_playwright() as p:
    browser = p.chromium.launch(headless=False, slow_mo=50)
    page = browser.new_page()
    page.goto(url)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_2451/2539692435.py in <module>
# ----> 1 with sync_playwright() as p:
#       2     browser = p.chromium.launch(headless=False, slow_mo=50)
#       3     page = browser.new_page()
#       4     page.goto(url)
#
# ~/anaconda3/envs/ws/lib/python3.9/site-packages/playwright/sync_api/_context_manager.py in __enter__(self)
#      42             self._own_loop = True
#      43         if self._loop.is_running():
# ---> 44             raise Error(
#      45                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      46 Please use the Async API instead."""
#
# Error: It looks like you are using Playwright Sync API inside the asyncio loop.
# Please use the Async API instead.
